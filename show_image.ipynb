# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
expamles = np.load('data/training_data.npy', allow_pickle=True)

# %%
label = expamles[0][1]

# %%
img = expamles[0][0].reshape(28,28)
plt.title("label = " + str(label))
plt.imshow(img, interpolation='none', cmap='Blues')
plt.show()
